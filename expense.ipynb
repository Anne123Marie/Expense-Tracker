# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\ibmuser\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Load dataset
df = pd.read_csv("Income_expense_data.csv")
# Group by year and sum income
total_income_per_year = df.groupby("REF_DATE")["Income"].sum()
# Display results
print(total_income_per_year)
# Out:
# REF_DATE
# 2010    231332020.0
# 2011    236453650.0
# 2012    240630900.0
# 2013    244531010.0
# 2014    248958970.0
# 2015    252134020.0
# 2016    255105340.0
# 2017    259694610.0
# 2019    268610440.0
# 2021    281113150.0
# Name: Income, dtype: float64

# %%
# Group by province and calculate the average expense

avg_expense_per_province = df.groupby("GEO")["Expense"].mean()

# Display results
print(avg_expense_per_province)
# Out:
# GEO
# Province 1      9913.831207
# Province 10     9294.256487
# Province 11    10097.058175
# Province 12    12217.614688
# Province 13    10725.302000
# Province 2      8409.790196
# Province 3      8935.938062
# Province 4      8601.477487
# Province 5      8689.465070
# Province 6      8174.689311
# Province 7      8358.220356
# Province 8     10683.486540
# Province 9     11046.595285
# Name: Expense, dtype: float64

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl.metadata (103 kB)
#      ---------------------------------------- 0.0/104.0 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.0 kB ? eta -:--:--
#      -------------- ---------------------- 41.0/104.0 kB 495.5 kB/s eta 0:00:01
#      -----------------------------------  102.4/104.0 kB 991.0 kB/s eta 0:00:01
#      -----------------------------------  102.4/104.0 kB 991.0 kB/s eta 0:00:01
#      ------------------------------------ 104.0/104.0 kB 548.1 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.1-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.7/8.1 MB 21.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/8.1 MB 12.9 MB/s eta 0:00:01
#    ------- -------------------------------- 1.5/8.1 MB 11.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/8.1 MB 10.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.1 MB 9.5 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.1 MB 10.0 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.1 MB 9.5 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/8.1 MB 9.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.0/8.1 MB 9.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.4/8.1 MB 9.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.1 MB 9.1 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 8.8 MB/s eta 0:00:01
#    ------------------------------- -------- 6.4/8.1 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.9/8.1 MB 9.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.2/8.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.1 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.7 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp311-cp311-win_amd64.whl (219 kB)
#    ---------------------------------------- 0.0/219.8 kB ? eta -:--:--
#    --------------------------------------  215.0/219.8 kB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 219.8/219.8 kB 3.3 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.2 MB 14.9 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 10.5 MB/s eta 0:00:01
#    ------------------------------ --------- 1.7/2.2 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/72.0 kB ? eta -:--:--
#    ---------------------------------------  71.7/72.0 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 72.0/72.0 kB 493.8 kB/s eta 0:00:00
# Downloading pillow-11.2.0-cp311-cp311-win_amd64.whl (13.8 MB)
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.8 MB 991.0 kB/s eta 0:00:14
#    ---------------------------------------- 0.1/13.8 MB 1.1 MB/s eta 0:00:13
#    - -------------------------------------- 0.4/13.8 MB 2.6 MB/s eta 0:00:06
#    -- ------------------------------------- 1.0/13.8 MB 5.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/13.8 MB 5.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/13.8 MB 4.7 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/13.8 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/13.8 MB 4.7 MB/s eta 0:00:03
#    ------ --------------------------------- 2.4/13.8 MB 5.4 MB/s eta 0:00:03
#    ------- -------------------------------- 2.7/13.8 MB 5.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/13.8 MB 5.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.4/13.8 MB 5.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/13.8 MB 6.3 MB/s eta 0:00:02
#    ------------ --------------------------- 4.3/13.8 MB 6.6 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.8 MB 6.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.8 MB 6.4 MB/s eta 0:00:02
#    -------------- ------------------------- 4.9/13.8 MB 6.1 MB/s eta 0:00:02
#    --------------- ------------------------ 5.3/13.8 MB 6.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.0/13.8 MB 6.6 MB/s eta 0:00:02
#    ------------------ --------------------- 6.5/13.8 MB 6.8 MB/s eta 0:00:02
#    ------------------- -------------------- 6.8/13.8 MB 6.9 MB/s eta 0:00:02
#    -------------------- ------------------- 7.1/13.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.6/13.8 MB 7.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.3/13.8 MB 7.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.8/13.8 MB 7.5 MB/s eta 0:00:01
#    --------------------------- ------------ 9.4/13.8 MB 7.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.9/13.8 MB 7.7 MB/s eta 0:00:01
#    ------------------------------ --------- 10.4/13.8 MB 8.5 MB/s eta 0:00:01
#    ------------------------------- -------- 11.0/13.8 MB 8.6 MB/s eta 0:00:01
#    --------------------------------- ------ 11.5/13.8 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.1/13.8 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.6/13.8 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------- -- 13.0/13.8 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 13.3/13.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  13.8/13.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  13.8/13.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  13.8/13.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  13.8/13.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  13.8/13.8 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 13.8/13.8 MB 7.8 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#    ------------------------------------ --- 102.4/111.1 kB ? eta -:--:--
#    ---------------------------------------- 111.1/111.1 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pillow-11.2.0 pyparsing-3.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\ibmuser\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
 
# Group by year and sum income & expense

yearly_data = df.groupby("REF_DATE")[["Income", "Expense"]].sum()

# Plot the data
plt.figure(figsize=(10, 5))

plt.plot(yearly_data.index,yearly_data["Income"], marker='o', linestyle='-', label="Total Income", color='green')

plt.plot(yearly_data.index,yearly_data["Expense"], marker='o', linestyle='-', label="Total Expense", color='red')


# Labels and title
plt.xlabel("Year")
plt.ylabel("Amount (in units)")
plt.title("Income vs. Expense Trend (2010–2021)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Group by family type and calculate the average income

avg_income_family = df.groupby("Family type")["Income"].mean()

# Display results
print(avg_income_family.sort_values(ascending=False))
# Out:
# Family type
# Couple families    190022.944771
# Name: Income, dtype: float64

# %%
# Group by Age of older adult and calculate the average expense

avg_expense_by_age = df.groupby("Age of older adult")["Expense"].mean()

# Display results
print(avg_expense_by_age.sort_values(ascending=False))
# Out:
# Age of older adult
# 55 to 64 years    17136.686247
# 45 to 54 years    11196.223385
# Total all ages     9476.128054
# 35 to 44 years     8554.008208
# 25 to 34 years     6509.507579
# 0 to 24 years      4834.847216
# Name: Expense, dtype: float64

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\ibmuser\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np

#compute correlation

correlation =np.corrcoef(df["Income"],df["Expense"])[0, 1]

# Display result
print("Correlation between Income and Expense:",correlation)
# Out:
# Correlation between Income and Expense: nan

# %%
# Group by income quintile and sum expenses

expense_by_quintile = df.groupby("Before-tax household income quintile")["Expense"].sum()

# Display results
print(expense_by_quintile.sort_values(ascending=False))
# Out:
# Before-tax household income quintile
# Highest quintile    36758192.0
# Fourth quintile     24609299.0
# All quintiles       20942243.0
# Third quintile      18758940.0
# Second quintile     14171198.0
# Lowest quintile     10158014.0
# Name: Expense, dtype: float64

# %%
# Group by province and sum income and expenses
income_expense_ratio = df.groupby("GEO")[["Income", "Expense"]].sum()

# calculate the ratio
income_expense_ratio["Ratio"] = income_expense_ratio["Income"] / income_expense_ratio["Expense"]

# Display results
print(income_expense_ratio.sort_values(by="Ratio", ascending=False))
# Out:
#                    Income     Expense       Ratio
# GEO
# Province 1   1.814789e+09  10102194.0  179.643059
# Province 9   4.170304e+08  11245434.0   37.084418
# Province 5   5.107633e+07   8706844.0    5.866228
# Province 7   4.373935e+07   8458519.0    5.171041
# Province 11  4.881694e+07  10066767.0    4.849317
# Province 2   3.358644e+07   8577986.0    3.915423
# Province 6   2.656316e+07   8182864.0    3.246194
# Province 3   1.727165e+07   8944874.0    1.930899
# Province 10  1.397480e+07   9312845.0    1.500594
# Province 4   1.218785e+07   8214411.0    1.483716
# Province 12  1.521275e+07  12144309.0    1.252665
# Province 13  1.251485e+07  10725302.0    1.166853
# Province 8   1.180059e+07  10715537.0    1.101260

# %%
# plot histogram 
plt.figure(figsize=(8,5))
plt.hist(df["Expense"],bins=20, color='blue', alpha=0.7, edgecolor='black')

# Labels and title
plt.xlabel("Household Expense")

plt.ylabel("Frequency")

plt.title("Distribution of Household Expenses")

plt.grid(axis='y')

plt.show()

# %%
# Filter data for highest & lowest income quintiles

high_income = df[df["Before-tax household income quintile"] == "Highest"]
low_income = df[df["Before-tax household income quintile"] == "Lowest"]

# Group by year and sum income
high_income_trend = high_income.groupby("REF_DATE")["Income"].sum()
low_income_trend = low_income.groupby("REF_DATE")["Income"].sum()

# Plot the data
plt.figure(figsize=(10, 5))
plt.plot(high_income_trend.index, high_income_trend, marker='o', linestyle='-', label="Highest Income Quintile", color='blue')
plt.plot(low_income_trend.index, low_income_trend, marker='o', linestyle='-', label="Lowest Income Quintile", color='red')

# Labels and title
plt.xlabel("Year")
plt.ylabel("Total Income")
plt.title("Income Gap Trend (2010–2021)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# group by province and calculate median expense 
median_expense_province =df.groupby("GEO")["Expense"].median()

#display results
print(median_expense_province.sort_values(ascending=False))
# Out:
# GEO
# Province 12    3892.0
# Province 8     3552.0
# Province 9     3548.5
# Province 13    3493.5
# Province 11    3331.0
# Province 1     3277.0
# Province 4     3139.0
# Province 3     3084.0
# Province 10    3017.0
# Province 5     3000.5
# Province 2     2954.5
# Province 6     2866.0
# Province 7     2762.5
# Name: Expense, dtype: float64

# %%
#count number of records per province
record_count =df["GEO"].value_counts()

#display results 
print(record_count)
# Out:
# GEO
# Province 1     1020
# Province 2     1020
# Province 3     1020
# Province 4     1020
# Province 5     1020
# Province 6     1020
# Province 7     1020
# Province 8     1020
# Province 9     1020
# Province 10    1020
# Province 11    1020
# Province 12    1020
# Province 13    1020
# Name: count, dtype: int64

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ibmuser\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 640.0 kB/s eta 0:00:01
#    ------------ --------------------------- 92.2/294.9 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 286.7/294.9 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\ibmuser\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# Plot boxplot
plt.figure(figsize=(10, 5))
sns.boxplot(x=df["Before-tax household income quintile"], y=df["Expense"])

# Labels and title
plt.xlabel("Income Quintile")
plt.ylabel("Household Expense")
plt.title("Expense Distribution by Income Quintile")
plt.show()

# %%
# group by age and sum income & expense
age_savings = df.groupby("Age of older adult")[["Income", "Expense"]].sum()

# calculate saving ratio 
age_savings["Savings Ratio"] = age_savings["Income"] / age_savings["Expense"]

#display results
print(age_savings.sort_values(by="Savings Ratio", ascending=False))
# Out:
#                           Income     Expense  Savings Ratio
# Age of older adult
# Total all ages      1.386850e+09  20942243.0      66.222600
# 35 to 44 years      2.942892e+08  18758940.0      15.687945
# 45 to 54 years      3.232403e+08  24609299.0      13.134885
# 25 to 34 years      1.840406e+08  14171198.0      12.986945
# 55 to 64 years      3.115484e+08  36758192.0       8.475619
# 0 to 24 years       1.859581e+07  10158014.0       1.830654

# %%
#Group by year and sum income
yearly_income = df.groupby("REF_DATE")["Income"].sum()

# Calculate percentage growth
income_growth = yearly_income.pct_change() * 100

# Display results
print(income_growth)
# Out:
# REF_DATE
# 2010         NaN
# 2011    2.213974
# 2012    1.766625
# 2013    1.620785
# 2014    1.810797
# 2015    1.275331
# 2016    1.178468
# 2017    1.798971
# 2019    3.433198
# 2021    4.654588
# Name: Income, dtype: float64

# %%
# group by year and sum income quintile, then sum expenses 
expense_trend = df.groupby(["REF_DATE", "Before-tax household income quintile"])["Expense"].sum().unstack()

# plot the data 
expense_trend.plot(figsize=(12, 6), marker='o')

# Labels and title
plt.xlabel("Year")
plt.ylabel("Total Expenses")
plt.title("Expense Trends by Income Quintile")
plt.legend(title="Income Quintile")
plt.grid (True)
plt.show()

# %%
pip install xlabel
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement xlable (from versions: none)
# ERROR: No matching distribution found for xlable
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\ibmuser\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# group by province and sum income & expense

province_data =df.groupby("GEO")[["Income","Expense"]].sum()

#scatter plot 
plt.figure(figsize=(8,5))
sns.scatterplot(x=province_data["Income"],y=province_data["Expense"],hue=province_data.index, s=100)

# lables and title 
plt.xlabel("total Income")
plt.xlabel("total Expenses")
plt.xlabel(" Income vs.Expenses by province")
plt.show()

# %%
# count frequency of each expense category 
expense_category_counts = df["Household expenditures, summary-level categories"].value_counts()

# display results 
print(expense_category_counts)
# Out:
# Household expenditures, summary-level categories
# Total expenditure                                          780
# Food purchased from stores                                 780
# Food purchased from restaurants                            780
# Shelter                                                    780
# Principal accommodation                                    780
# Rented living quarters                                     780
# Owned living quarters                                      780
# Water, fuel and electricity for principal accommodation    780
# Other accommodation                                        780
# Household operations                                       780
# Communications                                             780
# Household furnishings and equipment                        780
# Household furnishings                                      780
# Household equipment                                        780
# Household appliances                                       780
# Clothing and accessories                                   780
# Transportation                                             780
# Name: count, dtype: int64

# %%
# Count frequency of each expense category
expense_category_counts = df["Household expenditures, summary-level categories"].value_counts()
# Display results
print(expense_category_counts)
# Out:
# Household expenditures, summary-level categories
# Total expenditure                                          780
# Food purchased from stores                                 780
# Food purchased from restaurants                            780
# Shelter                                                    780
# Principal accommodation                                    780
# Rented living quarters                                     780
# Owned living quarters                                      780
# Water, fuel and electricity for principal accommodation    780
# Other accommodation                                        780
# Household operations                                       780
# Communications                                             780
# Household furnishings and equipment                        780
# Household furnishings                                      780
# Household equipment                                        780
# Household appliances                                       780
# Clothing and accessories                                   780
# Transportation                                             780
# Name: count, dtype: int64
